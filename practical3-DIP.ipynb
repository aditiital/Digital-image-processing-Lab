# %% [markdown]
# <a href="https://colab.research.google.com/github/aditiital/Digital-image-processing/blob/main/practical3-DIP.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
# Read image
img = cv2.imread('/content/cartoon.webp', 0)
# Histogram Equalization
equalized = cv2.equalizeHist(img)
# Display Images
plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title("Original Image")
plt.subplot(1,2,2)
plt.imshow(equalized, cmap='gray')
plt.title("Enhanced Image")
# Histogram Display
plt.figure(figsize=(10,5))

plt.subplot(1,2,1)
plt.hist(img.ravel(), 256, [0,256])
plt.title("Original Histogram")
plt.subplot(1,2,2)
plt.hist(equalized.ravel(), 256, [0,256])
plt.title("Equalized Histogram")
plt.show()
# Out:
# /tmp/ipykernel_1428/343417095.py:19: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(img.ravel(), 256, [0,256])
# /tmp/ipykernel_1428/343417095.py:22: MatplotlibDeprecationWarning: Passing the range parameter of hist() positionally is deprecated since Matplotlib 3.9; the parameter will become keyword-only in 3.11.
#   plt.hist(equalized.ravel(), 256, [0,256])
