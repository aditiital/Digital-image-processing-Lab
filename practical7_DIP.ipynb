# %% [markdown]
# <a href="https://colab.research.google.com/github/aditiital/Digital-image-processing-Lab/blob/main/Practical7_dip.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np
img = cv2.imread('/content/images.jpeg', 0)
# Apply Otsu's Thresholding
ret, segmented = cv2.threshold(
 img,
 0, # threshold value ignored by Otsu
 255,
 cv2.THRESH_BINARY + cv2.THRESH_OTSU
)
# Display Images
plt.figure(figsize=(10,4))
plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title("Original Image")
plt.subplot(1,2,2)
plt.imshow(segmented, cmap='gray')
plt.title("Segmented Image")
# Out:
# Text(0.5, 1.0, 'Segmented Image')
